# %%
import pyvista as pv
import numpy as np
import matplotlib.pyplot as plt
import os
import numpy as np
import pandas as pd

def load_mesh_from_folder(remeshed_path, clipped_path):
    """Load mesh data from a folder containing remeshed and clipped samples.
    Args:
        remeshed_path (str): Path to the folder containing remeshed samples.
        clipped_path (str): Path to the folder containing clipped samples.
    Returns:
        list: A list of tuples containing (remeshed_mesh_path, clipped_mesh_path).
    """
    mesh_pairs = []
    for samples_name in sorted(os.listdir(remeshed_path)):
        if not samples_name.startswith('sample_'):
            continue
        scalar_field_path = os.path.join(remeshed_path, samples_name, 'scalars.csv')
        remeshed_mesh_dir = os.path.join(remeshed_path, samples_name, 'meshes')
        clipped_mesh_dir = os.path.join(clipped_path, samples_name, 'meshes')
        
        if not os.path.isdir(remeshed_mesh_dir) or not os.path.isdir(clipped_mesh_dir):
            continue 
        if not os.path.isfile(scalar_field_path):
            print(f"⚠️ Scalar field file not found for {samples_name}. Skipping.")
            continue
            
        remeshed_mesh = os.path.join(remeshed_mesh_dir, 'mesh_000000000.cgns') 
        clipped_mesh = os.path.join(clipped_mesh_dir, 'mesh_000000000.cgns')
        scalar_df = pd.read_csv(scalar_field_path) 

        if os.path.isfile(remeshed_mesh) and os.path.isfile(clipped_mesh):
            mesh_pairs.append((remeshed_mesh, clipped_mesh, scalar_df))
            print(f"✅ Found mesh pair: {samples_name}") 
    
    return mesh_pairs

data_remeshed_path = './AirfRANS_remeshed'
data_clipped_path = './AirfRANS_clipped'

mesh_data = load_mesh_from_folder(data_clipped_path, data_remeshed_path) 
print(f"Found {len(mesh_data)} mesh pairs.")
# Out:
# ✅ Found mesh pair: sample_000000000
# ✅ Found mesh pair: sample_000000010
# ✅ Found mesh pair: sample_000000020
# ✅ Found mesh pair: sample_000000030
# ✅ Found mesh pair: sample_000000040
# ✅ Found mesh pair: sample_000000050
# ✅ Found mesh pair: sample_000000100
# ✅ Found mesh pair: sample_000000300
# ✅ Found mesh pair: sample_000000500
# ✅ Found mesh pair: sample_000000750
# ✅ Found mesh pair: sample_000000999
# Found 11 mesh pairs.

# %%
def process_mesh_pair(remeshed_path, clipped_path ):
    """
    Process a pair of remeshed and clipped meshes with consistent scaling
    Args:
        remeshed_path (str): Path to remeshed mesh file
        clipped_path (str): Path to clipped mesh file   
    Returns:
        tuple: (remeshed_data, clipped_data, global_ranges) for consistent scaling
    """
    
    def extract_mesh_data(filepath, mesh_type):
        """Extract data from a single mesh file"""
        print(f"\nProcessing {mesh_type} mesh: {os.path.basename(filepath)}")
        
        # Read the mesh
        reader = pv.CGNSReader(filepath)
        reader.load_boundary_patch = False
        mesh = reader.read().combine()
        
        # Get bounds and create sampling plane
        bounds = mesh.bounds
        x_min, x_max, y_min, y_max, z_min, z_max = bounds
        resolution = 512
        
        plane = pv.Plane(center=[(x_min + x_max)/2, (y_min + y_max)/2, 0], 
                        direction=[0, 0, 1], 
                        i_size=x_max - x_min, 
                        j_size=y_max - y_min, 
                        i_resolution=resolution, 
                        j_resolution=resolution)
        
        # Sample the data
        sampled_mesh = plane.sample(mesh)
        n_points = sampled_mesh.n_points
        actual_resolution = int(np.sqrt(n_points))
        
        print(f"  Available arrays: {sampled_mesh.array_names}")
        print(f"  Resolution: {actual_resolution}x{actual_resolution}")
        
        # Extract data arrays
        data_dict = {}
        for array_name in ['nut', 'p', 'Ux', 'Uy', 'implicit_distance']:
            if array_name in sampled_mesh.array_names:
                data = sampled_mesh[array_name]
                
                # Reshape data
                if len(data) == actual_resolution * actual_resolution:
                    data = data.reshape(actual_resolution, actual_resolution)
                else:
                    # Interpolate to regular grid
                    from scipy.interpolate import griddata
                    points = sampled_mesh.points
                    x, y = points[:, 0], points[:, 1]
                    xi = np.linspace(x.min(), x.max(), resolution)
                    yi = np.linspace(y.min(), y.max(), resolution)
                    Xi, Yi = np.meshgrid(xi, yi)
                    data = griddata((x, y), data, (Xi, Yi), method='linear')
                
                data_dict[array_name] = data
                print(f"  {array_name}: range [{np.nanmin(data):.6f}, {np.nanmax(data):.6f}]")
        
        return data_dict, bounds
    
    # Process both meshes
    remeshed_data, remeshed_bounds = extract_mesh_data(remeshed_path, "REMESHED")
    clipped_data, clipped_bounds = extract_mesh_data(clipped_path, "CLIPPED")
    
    # Calculate global ranges for consistent scaling
    global_ranges = {}
    for var in ['nut', 'p', 'Ux', 'Uy']:
        if var in remeshed_data and var in clipped_data:
            # Find global min/max across both meshes
            remeshed_vals = remeshed_data[var]
            clipped_vals = clipped_data[var]
            
            global_min = min(np.nanmin(remeshed_vals), np.nanmin(clipped_vals))
            global_max = max(np.nanmax(remeshed_vals), np.nanmax(clipped_vals))
            
            global_ranges[var] = (global_min, global_max)
            print(f"\nGlobal range for {var}: [{global_min:.6f}, {global_max:.6f}]")
    
    return remeshed_data, clipped_data, global_ranges

# %%
# Generate detailed vector plot of the first mesh pair with reduced arrow density
if mesh_data:
    remeshed_mesh_path, clipped_mesh_path, scalar_df = mesh_data[0]
    
    # Process the mesh to get flow field data
    remeshed_data, clipped_data, global_ranges = process_mesh_pair(remeshed_mesh_path, clipped_mesh_path)
    
    # Load the mesh using CGNSReader for proper flow field extraction
    reader = pv.CGNSReader(remeshed_mesh_path)
    reader.load_boundary_patch = False
    mesh = reader.read().combine()
    
    # Create vector plot using velocity components
    if 'Ux' in mesh.array_names and 'Uy' in mesh.array_names:
        # Check if velocity data is cell data or point data and convert to point data if needed
        if mesh['Ux'].size == mesh.n_cells:
            # Convert cell data to point data
            mesh = mesh.cell_data_to_point_data()
        
        # Create velocity vectors
        ux = mesh['Ux']
        uy = mesh['Uy']
        uz = np.zeros(len(ux))
        mesh['velocity'] = np.column_stack([ux, uy, uz])
        
        # Create plotter with larger size
        plotter = pv.Plotter(window_size=[1200, 800])
        
        # Add mesh with pressure coloring
        if 'p' in mesh.array_names:
            plotter.add_mesh(mesh, scalars='p', opacity=0.6, cmap='coolwarm', 
                           show_scalar_bar=True, scalar_bar_args={'title': 'Pressure'})
        else:
            plotter.add_mesh(mesh, color='lightgray', opacity=0.6)
        
        # Subsample the mesh for vector visualization with much lower density
        bounds = mesh.bounds
        x_min, x_max, y_min, y_max = bounds[0], bounds[1], bounds[2], bounds[3]
        
        # Reduce arrow density significantly
        nx, ny = 25, 15  # Much fewer vectors for cleaner visualization
        x_sample = np.linspace(x_min + 0.3, x_max - 0.3, nx)
        y_sample = np.linspace(y_min + 0.3, y_max - 0.3, ny)
        
        sample_points = []
        for y in y_sample:
            for x in x_sample:
                sample_points.append([x, y, 0])
        
        sample_grid = pv.PolyData(np.array(sample_points))
        
        # Interpolate velocity data to sample points
        sampled_mesh = sample_grid.sample(mesh)
        
        # Filter out points with very small velocities or invalid data
        velocity_magnitude = np.sqrt(sampled_mesh['Ux']**2 + sampled_mesh['Uy']**2)
        # Use a higher threshold to show only significant flow
        valid_mask = velocity_magnitude > 0.5 * np.nanmax(velocity_magnitude)
        
        if np.any(valid_mask):
            # Create filtered sample points and vectors
            filtered_points = sampled_mesh.points[valid_mask]
            filtered_ux = sampled_mesh['Ux'][valid_mask]
            filtered_uy = sampled_mesh['Uy'][valid_mask]
            filtered_uz = np.zeros(len(filtered_ux))
            
            filtered_vectors = np.column_stack([filtered_ux, filtered_uy, filtered_uz])
            
            # Create a new polydata with filtered points
            vector_mesh = pv.PolyData(filtered_points)
            vector_mesh['velocity'] = filtered_vectors
            
            # Add vector arrows with better scaling
            arrows = vector_mesh.glyph(orient='velocity', scale='velocity', 
                                     factor=0.005, geom=pv.Arrow())
            
            plotter.add_mesh(arrows, color='blue', show_scalar_bar=False)
            
            print(f"✅ Generated cleaner vector plot with {len(filtered_points)} arrows")
        else:
            print("⚠️ No valid velocity vectors found for visualization")
        
        # Enhance the plot
        plotter.add_title(f"Vector Field - Sample {os.path.basename(os.path.dirname(os.path.dirname(remeshed_mesh_path)))}")
        plotter.camera_position = 'xy'
        
        # Remove axis lines and ticks
        plotter.show_axes = False
        
        plotter.show()
        
    else:
        print("⚠️ Velocity components 'Ux' and 'Uy' not found in mesh data")
        print(f"Available arrays: {mesh.array_names}")
# Out:
# Processing REMESHED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'vtkOriginalPointIds', 'cell_ids', 'vtkOriginalCellIds', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [0.000000, 0.005274]
#   p: range [-580.084809, 474.401467]
#   Ux: range [0.000000, 43.918259]
#   Uy: range [-31.265326, 10.550596]
#   implicit_distance: range [-3.354337, 0.000000]
#
# Processing CLIPPED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'zone_0', 'zone_1', 'zone_2', 'zone_3', 'zone_4', 'zone_5', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [0.000000, 0.005273]
#   p: range [-580.088350, 474.201043]
#   Ux: range [0.000000, 43.906636]
#   Uy: range [-31.224781, 10.547611]
#   implicit_distance: range [-3.354337, 0.000000]
#
# Global range for nut: [0.000000, 0.005274]
#
# Global range for p: [-580.088350, 474.401467]
#
# Global range for Ux: [0.000000, 43.918259]
#
# Global range for Uy: [-31.265326, 10.550596]
# ✅ Generated cleaner vector plot with 370 arrows
# /Users/saikirannunemunthala/Files/Lectures/Thesis/AirfranceDatasetAnalysis/.venv/lib/python3.13/site-packages/pyvista/jupyter/notebook.py:36: UserWarning: Failed to use notebook backend:
#
# No module named 'trame'
#
# Falling back to a static output.
#   warnings.warn(
# <PIL.Image.Image image mode=RGB size=1200x800>
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
def extract_airfoil_surface_and_compute_forces(data, mesh_type=""):
    """
    Extracts airfoil surface and computes pressure and viscous forces.
    This is a modular function to be called by the main coefficient calculation logic.
    """
    p = data.get('p')
    Ux = data.get('Ux')
    Uy = data.get('Uy')

    if p is None or Ux is None or Uy is None:
        print(f"⚠️  Warning: Missing one or more required fields ('p', 'Ux', 'Uy') in {mesh_type} data.")
        return 0, 0, 0, 0

    nut = data.get('nut', np.zeros_like(p))
    
    if 'implicit_distance' in data:
        distance = data['implicit_distance']
        surface_mask = np.abs(distance) < 0.01
    else:
        vel_mag = np.sqrt(Ux**2 + Uy**2)
        surface_mask = vel_mag < 0.1 * np.nanmax(vel_mag)
    
    if not np.any(surface_mask):
        print(f"⚠️  Warning: No airfoil surface found in {mesh_type} data.")
        return 0, 0, 0, 0
    
    surface_indices = np.where(surface_mask)
    n_surface_points = len(surface_indices[0])
    
    if n_surface_points < 10:
        print(f"⚠️  Warning: Very few surface points found ({n_surface_points}) in {mesh_type}.")
        return 0, 0, 0, 0
    
    print(f"✅ Found {n_surface_points} surface points in {mesh_type}")
    
    pressure_force_x, pressure_force_y = 0, 0
    viscous_force_x, viscous_force_y = 0, 0
    
    dy, dx = np.gradient(distance) if 'implicit_distance' in data else np.gradient(vel_mag)
    rho, mu = 1.0, 1.0
    total_surface_area = 0
    
    for i, j in zip(surface_indices[0], surface_indices[1]):
        if 'implicit_distance' in data:
            nx, ny = dx[i, j], dy[i, j]
            norm = np.sqrt(nx**2 + ny**2)
            if norm > 1e-12:
                nx /= norm
                ny /= norm
            else: continue
        else:
            nx, ny = 1.0, 0.0
        
        pressure_force_x += p[i, j] * nx
        pressure_force_y += p[i, j] * ny
        
        if i > 0 and i < p.shape[0]-1 and j > 0 and j < p.shape[1]-1:
            dudx = (Ux[i, j+1] - Ux[i, j-1]) / 2.0
            dudy = (Ux[i+1, j] - Ux[i-1, j]) / 2.0
            dvdx = (Uy[i, j+1] - Uy[i, j-1]) / 2.0
            dvdy = (Uy[i+1, j] - Uy[i-1, j]) / 2.0
            tau_xx = (mu + nut[i, j]) * 2 * dudx
            tau_yy = (mu + nut[i, j]) * 2 * dvdy
            tau_xy = (mu + nut[i, j]) * (dudy + dvdx)
            viscous_force_x += tau_xx * nx + tau_xy * ny
            viscous_force_y += tau_xy * nx + tau_yy * ny
        
        total_surface_area += 1
    
    if total_surface_area > 0:
        pressure_force_x /= total_surface_area
        pressure_force_y /= total_surface_area
        viscous_force_x /= total_surface_area
        viscous_force_y /= total_surface_area
    
    total_force_x = pressure_force_x + viscous_force_x
    total_force_y = pressure_force_y + viscous_force_y
    
    return total_force_x, total_force_y, pressure_force_x, viscous_force_x

def calculate_coefficients(data, mesh_type, angle_of_attack):
    """Helper to calculate coefficients for a single dataset."""
    print(f"\n--- Processing {mesh_type} Data ---")
    force_x, force_y, pressure_force, viscous_force = extract_airfoil_surface_and_compute_forces(data, mesh_type)
    
    alpha_rad = np.radians(angle_of_attack)
    cos_alpha, sin_alpha = np.cos(alpha_rad), np.sin(alpha_rad)
    
    drag_force = force_x * cos_alpha + force_y * sin_alpha
    lift_force = -force_x * sin_alpha + force_y * cos_alpha
    
    chord_length, rho_inf, V_inf = 1.0, 1.0, 1.0
    q_inf = 0.5 * rho_inf * V_inf**2
    
    drag_coefficient = drag_force / (q_inf * chord_length) if q_inf * chord_length != 0 else 0
    lift_coefficient = lift_force / (q_inf * chord_length) if q_inf * chord_length != 0 else 0
    pressure_drag_coeff = pressure_force / (q_inf * chord_length) if q_inf * chord_length != 0 else 0
    viscous_drag_coeff = viscous_force / (q_inf * chord_length) if q_inf * chord_length != 0 else 0
    
    print(f"Drag Force: {drag_force:.6f}, Lift Force: {lift_force:.6f}")
    
    return {
        "drag_coefficient": drag_coefficient,
        "lift_coefficient": lift_coefficient,
        "pressure_drag_coeff": pressure_drag_coeff,
        "viscous_drag_coeff": viscous_drag_coeff,
    }

def compute_drag_lift_coefficients_comparison(remeshed_data, clipped_data, global_ranges, angle_of_attack=0.0):
    """
    Computes and compares drag and lift coefficients from remeshed and clipped data.
    """
    remeshed_results = calculate_coefficients(remeshed_data, "REMESHED", angle_of_attack)
    clipped_results = calculate_coefficients(clipped_data, "CLIPPED", angle_of_attack)
    
    return remeshed_results, clipped_results

# %%
output_csv_path = 'coefficient_comparison_results.csv'

# %%
# --- Configuration --- 
all_results = []

# --- Main Processing Loop ---
for remeshed_path, clipped_path, scalar_df in mesh_data:
    sample_name = os.path.basename(os.path.dirname(os.path.dirname(remeshed_path)))
    print(f"\n\n{'='*20} Processing Sample: {sample_name} {'='*20}")

    # Extract reference values from the scalar DataFrame
    if not scalar_df.empty:
        reference_conditions = {
            'C_D': scalar_df['C_D'].iloc[0],
            'C_L': scalar_df['C_L'].iloc[0],
            'angle_of_attack': scalar_df['angle_of_attack'].iloc[0],
            'inlet_velocity': scalar_df['inlet_velocity'].iloc[0]
        }
        angle_of_attack = reference_conditions['angle_of_attack']
    else:
        print(f"⚠️ Warning: scalar_df is empty for {sample_name}. Using default angle of attack.")
        angle_of_attack = 0.0
        reference_conditions = {}

    # Process the mesh pair to get field data
    remeshed_data, clipped_data, global_ranges = process_mesh_pair(remeshed_path, clipped_path)

    # Compute coefficients for both datasets
    remeshed_coeffs, clipped_coeffs = compute_drag_lift_coefficients_comparison(
        remeshed_data, clipped_data, global_ranges, angle_of_attack
    )

    # Helper for safe percentage difference calculation
    def calculate_diff(val1, val2):
        if abs(val1) > 1e-9:
            return 100 * (val2 - val1) / val1
        return float('inf') if val1 != val2 else 0.0

    # Store results for this sample, including all coefficients and their differences
    result_entry = {
        'sample': sample_name,
        
        'remeshed_cd': remeshed_coeffs['drag_coefficient'],
        'clipped_cd': clipped_coeffs['drag_coefficient'],
        'reference_cd': reference_conditions.get('C_D', 'N/A'),
        'cd_diff_percent': calculate_diff(remeshed_coeffs['drag_coefficient'], clipped_coeffs['drag_coefficient']),
        
        'remeshed_cl': remeshed_coeffs['lift_coefficient'],
        'clipped_cl': clipped_coeffs['lift_coefficient'],
        'reference_cl': reference_conditions.get('C_L', 'N/A'),
        'cl_diff_percent': calculate_diff(remeshed_coeffs['lift_coefficient'], clipped_coeffs['lift_coefficient']),

        'remeshed_pressure_drag': remeshed_coeffs['pressure_drag_coeff'],
        'clipped_pressure_drag': clipped_coeffs['pressure_drag_coeff'],
        'pressure_drag_diff_percent': calculate_diff(remeshed_coeffs['pressure_drag_coeff'], clipped_coeffs['pressure_drag_coeff']),

        'remeshed_viscous_drag': remeshed_coeffs['viscous_drag_coeff'],
        'clipped_viscous_drag': clipped_coeffs['viscous_drag_coeff'],
        'viscous_drag_diff_percent': calculate_diff(remeshed_coeffs['viscous_drag_coeff'], clipped_coeffs['viscous_drag_coeff']),
    }
    all_results.append(result_entry)

# --- Save Results to CSV ---
results_df = pd.DataFrame(all_results)
results_df.to_csv(output_csv_path, index=False)

print(f"\n\n✅ All samples processed. Results saved to '{output_csv_path}'")

# --- Display Final Comparison Table for the last sample ---
print("\n\n" + "="*60)
print(f"=== FINAL SAMPLE ({sample_name}) COMPARISON ===")
print("="*60)
print(f"| {'Metric':<25} | {'Remeshed':<12} | {'Clipped':<12} | {'Difference (%)':<15} |")
print(f"|{'-'*27}|{'-'*14}|{'-'*14}|{'-'*18}|")

for key in remeshed_coeffs:
    rem_val = remeshed_coeffs[key]
    clip_val = clipped_coeffs[key]
    
    if abs(rem_val) > 1e-9:
        diff = 100 * (clip_val - rem_val) / rem_val
    else:
        diff = float('inf') if clip_val != rem_val else 0.0
        
    print(f"| {key:<25} | {rem_val:<12.6f} | {clip_val:<12.6f} | {diff:<15.2f} |")

print("="*60)
display(results_df.head())
# Out:
# ==================== Processing Sample: sample_000000000 ====================
#
# Processing REMESHED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'vtkOriginalPointIds', 'cell_ids', 'vtkOriginalCellIds', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [0.000000, 0.005274]
#   p: range [-580.084809, 474.401467]
#   Ux: range [0.000000, 43.918259]
#   Uy: range [-31.265326, 10.550596]
#   implicit_distance: range [-3.354337, 0.000000]
#
# Processing CLIPPED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'zone_0', 'zone_1', 'zone_2', 'zone_3', 'zone_4', 'zone_5', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [-0.000000, 0.005273]
#   p: range [-580.088350, 474.201043]
#   Ux: range [-0.000000, 43.906636]
#   Uy: range [-31.224781, 10.547611]
#   implicit_distance: range [-3.354337, 0.000000]
#
# Global range for nut: [-0.000000, 0.005274]
#
# Global range for p: [-580.088350, 474.401467]
#
# Global range for Ux: [-0.000000, 43.918259]
#
# Global range for Uy: [-31.265326, 10.550596]
#
# --- Processing REMESHED Data ---
# ✅ Found 1719 surface points in REMESHED
# Drag Force: -15.702287, Lift Force: -38.681186
#
# --- Processing CLIPPED Data ---
# ✅ Found 1723 surface points in CLIPPED
# Drag Force: -15.600032, Lift Force: -38.823678
#
#
# ==================== Processing Sample: sample_000000001 ====================
#
# Processing REMESHED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'vtkOriginalPointIds', 'cell_ids', 'vtkOriginalCellIds', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [0.000000, 0.005689]
#   p: range [-540.794473, 443.207383]
#   Ux: range [0.000000, 44.211172]
#   Uy: range [-8.093701, 30.808699]
#   implicit_distance: range [-3.354337, 0.000000]
#
# Processing CLIPPED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'zone_0', 'zone_1', 'zone_2', 'zone_3', 'zone_4', 'zone_5', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [0.000000, 0.005686]
#   p: range [-540.678448, 443.171603]
#   Ux: range [0.000000, 44.209518]
#   Uy: range [-8.083582, 27.874673]
#   implicit_distance: range [-3.354337, 0.000000]
#
# Global range for nut: [0.000000, 0.005689]
#
# Global range for p: [-540.794473, 443.207383]
#
# Global range for Ux: [0.000000, 44.211172]
#
# Global range for Uy: [-8.093701, 30.808699]
#
# --- Processing REMESHED Data ---
# ✅ Found 1614 surface points in REMESHED
# Drag Force: -21.404802, Lift Force: 80.572732
#
# --- Processing CLIPPED Data ---
# ✅ Found 1630 surface points in CLIPPED
# Drag Force: -20.642650, Lift Force: 76.954068
#
#
# ==================== Processing Sample: sample_000000002 ====================
#
# Processing REMESHED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'vtkOriginalPointIds', 'cell_ids', 'vtkOriginalCellIds', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [0.000000, 0.023578]
#   p: range [-3807.629136, 495.504150]
#   Ux: range [-46.368099, 69.915860]
#   Uy: range [-1.975211, 69.711600]
#   implicit_distance: range [-3.354566, 0.000000]
#
# Processing CLIPPED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'zone_0', 'zone_1', 'zone_2', 'zone_3', 'zone_4', 'zone_5', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [0.000000, 0.023569]
#   p: range [-3811.368278, 495.454743]
#   Ux: range [-34.711184, 67.423111]
#   Uy: range [-1.969770, 69.648705]
#   implicit_distance: range [-3.354566, 0.000000]
#
# Global range for nut: [0.000000, 0.023578]
#
# Global range for p: [-3811.368278, 495.504150]
#
# Global range for Ux: [-46.368099, 69.915860]
#
# Global range for Uy: [-1.975211, 69.711600]
#
# --- Processing REMESHED Data ---
# ✅ Found 999 surface points in REMESHED
# Drag Force: -75.925942, Lift Force: 231.829448
#
# --- Processing CLIPPED Data ---
# ✅ Found 1001 surface points in CLIPPED
# Drag Force: -75.680991, Lift Force: 230.872066
#
#
# ==================== Processing Sample: sample_000000003 ====================
#
# Processing REMESHED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'vtkOriginalPointIds', 'cell_ids', 'vtkOriginalCellIds', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [0.000000, 0.005806]
#   p: range [-536.736934, 479.456310]
#   Ux: range [0.000000, 43.607251]
#   Uy: range [-30.209723, 13.332791]
#   implicit_distance: range [-3.354324, 0.000000]
#
# Processing CLIPPED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'zone_0', 'zone_1', 'zone_2', 'zone_3', 'zone_4', 'zone_5', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [0.000000, 0.005799]
#   p: range [-536.582661, 479.216800]
#   Ux: range [0.000000, 43.593560]
#   Uy: range [-30.212172, 13.329244]
#   implicit_distance: range [-3.354324, 0.000000]
#
# Global range for nut: [0.000000, 0.005806]
#
# Global range for p: [-536.736934, 479.456310]
#
# Global range for Ux: [0.000000, 43.607251]
#
# Global range for Uy: [-30.212172, 13.332791]
#
# --- Processing REMESHED Data ---
# ✅ Found 2000 surface points in REMESHED
# Drag Force: -17.348849, Lift Force: -40.898651
#
# --- Processing CLIPPED Data ---
# ✅ Found 1999 surface points in CLIPPED
# Drag Force: -17.395951, Lift Force: -41.146116
#
#
# ==================== Processing Sample: sample_000000004 ====================
#
# Processing REMESHED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'vtkOriginalPointIds', 'cell_ids', 'vtkOriginalCellIds', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [0.000000, 0.006850]
#   p: range [-525.823257, 462.400085]
#   Ux: range [0.000000, 44.364347]
#   Uy: range [-12.946670, 27.208432]
#   implicit_distance: range [-3.354431, 0.000000]
#
# Processing CLIPPED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'zone_0', 'zone_1', 'zone_2', 'zone_3', 'zone_4', 'zone_5', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [0.000000, 0.006846]
#   p: range [-525.668688, 462.165185]
#   Ux: range [0.000000, 44.354741]
#   Uy: range [-12.945660, 27.206794]
#   implicit_distance: range [-3.354431, 0.000000]
#
# Global range for nut: [0.000000, 0.006850]
#
# Global range for p: [-525.823257, 462.400085]
#
# Global range for Ux: [0.000000, 44.364347]
#
# Global range for Uy: [-12.946670, 27.208432]
#
# --- Processing REMESHED Data ---
# ✅ Found 2026 surface points in REMESHED
# Drag Force: -19.363447, Lift Force: 72.770973
#
# --- Processing CLIPPED Data ---
# ✅ Found 2028 surface points in CLIPPED
# Drag Force: -19.330300, Lift Force: 72.532015
#
#
# ==================== Processing Sample: sample_000000005 ====================
#
# Processing REMESHED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'vtkOriginalPointIds', 'cell_ids', 'vtkOriginalCellIds', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [0.000000, 0.003849]
#   p: range [-168.932559, 291.034110]
#   Ux: range [0.000000, 36.553387]
#   Uy: range [-14.762932, 9.942608]
#   implicit_distance: range [-3.354373, 0.000000]
#
# Processing CLIPPED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'zone_0', 'zone_1', 'zone_2', 'zone_3', 'zone_4', 'zone_5', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [0.000000, 0.003845]
#   p: range [-168.915378, 290.415353]
#   Ux: range [0.000000, 36.549779]
#   Uy: range [-14.705891, 9.951222]
#   implicit_distance: range [-3.354373, 0.000000]
#
# Global range for nut: [0.000000, 0.003849]
#
# Global range for p: [-168.932559, 291.034110]
#
# Global range for Ux: [0.000000, 36.553387]
#
# Global range for Uy: [-14.762932, 9.951222]
#
# --- Processing REMESHED Data ---
# ✅ Found 862 surface points in REMESHED
# Drag Force: -10.069055, Lift Force: 43.251762
#
# --- Processing CLIPPED Data ---
# ✅ Found 868 surface points in CLIPPED
# Drag Force: -9.971168, Lift Force: 42.324658
#
#
# ==================== Processing Sample: sample_000000006 ====================
#
# Processing REMESHED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'vtkOriginalPointIds', 'cell_ids', 'vtkOriginalCellIds', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [0.000000, 0.004268]
#   p: range [-250.034712, 409.742021]
#   Ux: range [0.000000, 38.023216]
#   Uy: range [-13.774080, 21.732708]
#   implicit_distance: range [-3.354280, 0.000000]
#
# Processing CLIPPED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'zone_0', 'zone_1', 'zone_2', 'zone_3', 'zone_4', 'zone_5', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [-0.000000, 0.004267]
#   p: range [-249.803706, 409.732253]
#   Ux: range [-0.000000, 38.021956]
#   Uy: range [-13.775907, 21.704292]
#   implicit_distance: range [-3.354280, 0.000000]
#
# Global range for nut: [-0.000000, 0.004268]
#
# Global range for p: [-250.034712, 409.742021]
#
# Global range for Ux: [-0.000000, 38.023216]
#
# Global range for Uy: [-13.775907, 21.732708]
#
# --- Processing REMESHED Data ---
# ✅ Found 1357 surface points in REMESHED
# Drag Force: -13.646068, Lift Force: 14.069292
#
# --- Processing CLIPPED Data ---
# ✅ Found 1361 surface points in CLIPPED
# Drag Force: -13.594289, Lift Force: 13.949582
#
#
# ==================== Processing Sample: sample_000000007 ====================
#
# Processing REMESHED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'vtkOriginalPointIds', 'cell_ids', 'vtkOriginalCellIds', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [0.000000, 0.004371]
#   p: range [-237.146115, 428.767982]
#   Ux: range [0.000000, 38.059824]
#   Uy: range [-16.680268, 20.235480]
#   implicit_distance: range [-3.354431, 0.000000]
#
# Processing CLIPPED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'zone_0', 'zone_1', 'zone_2', 'zone_3', 'zone_4', 'zone_5', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [0.000000, 0.004369]
#   p: range [-237.059011, 428.845425]
#   Ux: range [0.000000, 38.006054]
#   Uy: range [-16.690876, 17.445742]
#   implicit_distance: range [-3.354431, 0.000000]
#
# Global range for nut: [0.000000, 0.004371]
#
# Global range for p: [-237.146115, 428.845425]
#
# Global range for Ux: [0.000000, 38.059824]
#
# Global range for Uy: [-16.690876, 20.235480]
#
# --- Processing REMESHED Data ---
# ✅ Found 1455 surface points in REMESHED
# Drag Force: -13.020993, Lift Force: 9.154211
#
# --- Processing CLIPPED Data ---
# ✅ Found 1459 surface points in CLIPPED
# Drag Force: -12.684762, Lift Force: 8.950308
#
#
# ==================== Processing Sample: sample_000000008 ====================
#
# Processing REMESHED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'vtkOriginalPointIds', 'cell_ids', 'vtkOriginalCellIds', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [0.000000, 0.008246]
#   p: range [-1054.240209, 473.870687]
#   Ux: range [0.000000, 49.755135]
#   Uy: range [-4.993051, 43.057261]
#   implicit_distance: range [-3.354583, 0.000000]
#
# Processing CLIPPED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'zone_0', 'zone_1', 'zone_2', 'zone_3', 'zone_4', 'zone_5', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [0.000000, 0.008240]
#   p: range [-1054.328201, 472.836315]
#   Ux: range [0.000000, 49.699405]
#   Uy: range [-4.987190, 43.086662]
#   implicit_distance: range [-3.354583, 0.000000]
#
# Global range for nut: [0.000000, 0.008246]
#
# Global range for p: [-1054.328201, 473.870687]
#
# Global range for Ux: [0.000000, 49.755135]
#
# Global range for Uy: [-4.993051, 43.086662]
#
# --- Processing REMESHED Data ---
# ✅ Found 1358 surface points in REMESHED
# Drag Force: -39.847582, Lift Force: 160.796430
#
# --- Processing CLIPPED Data ---
# ✅ Found 1358 surface points in CLIPPED
# Drag Force: -39.881630, Lift Force: 160.809755
#
#
# ==================== Processing Sample: sample_000000009 ====================
#
# Processing REMESHED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'vtkOriginalPointIds', 'cell_ids', 'vtkOriginalCellIds', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [0.000000, 0.006072]
#   p: range [-439.458787, 480.927648]
#   Ux: range [0.000000, 42.511943]
#   Uy: range [-17.709305, 23.652838]
#   implicit_distance: range [-3.354292, 0.000000]
#
# Processing CLIPPED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'zone_0', 'zone_1', 'zone_2', 'zone_3', 'zone_4', 'zone_5', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [-0.000000, 0.006068]
#   p: range [-439.407952, 480.625824]
#   Ux: range [-0.000000, 42.495326]
#   Uy: range [-17.708158, 23.642638]
#   implicit_distance: range [-3.354292, 0.000000]
#
# Global range for nut: [-0.000000, 0.006072]
#
# Global range for p: [-439.458787, 480.927648]
#
# Global range for Ux: [-0.000000, 42.511943]
#
# Global range for Uy: [-17.709305, 23.652838]
#
# --- Processing REMESHED Data ---
# ✅ Found 2244 surface points in REMESHED
# Drag Force: -15.634235, Lift Force: 19.074638
#
# --- Processing CLIPPED Data ---
# ✅ Found 2244 surface points in CLIPPED
# Drag Force: -15.699080, Lift Force: 19.072914
#
#
# ==================== Processing Sample: sample_000000010 ====================
#
# Processing REMESHED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'vtkOriginalPointIds', 'cell_ids', 'vtkOriginalCellIds', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [0.000000, 0.004281]
#   p: range [-261.713701, 409.351481]
#   Ux: range [0.000000, 38.302012]
#   Uy: range [-21.326368, 12.324440]
#   implicit_distance: range [-3.354423, 0.000000]
#
# Processing CLIPPED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'zone_0', 'zone_1', 'zone_2', 'zone_3', 'zone_4', 'zone_5', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [0.000000, 0.004280]
#   p: range [-261.875226, 409.296472]
#   Ux: range [0.000000, 38.300834]
#   Uy: range [-21.278332, 12.314386]
#   implicit_distance: range [-3.354423, 0.000000]
#
# Global range for nut: [0.000000, 0.004281]
#
# Global range for p: [-261.875226, 409.351481]
#
# Global range for Ux: [0.000000, 38.302012]
#
# Global range for Uy: [-21.326368, 12.324440]
#
# --- Processing REMESHED Data ---
# ✅ Found 1294 surface points in REMESHED
# Drag Force: -12.004171, Lift Force: 7.523598
#
# --- Processing CLIPPED Data ---
# ✅ Found 1294 surface points in CLIPPED
# Drag Force: -12.052237, Lift Force: 7.299657
#
#
# ==================== Processing Sample: sample_000000011 ====================
#
# Processing REMESHED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'vtkOriginalPointIds', 'cell_ids', 'vtkOriginalCellIds', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [0.000000, 0.028471]
#   p: range [-3382.318376, 512.156588]
#   Ux: range [-18.307669, 60.337895]
#   Uy: range [-5.650903, 61.449489]
#   implicit_distance: range [-3.354330, 0.000000]
#
# Processing CLIPPED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'zone_0', 'zone_1', 'zone_2', 'zone_3', 'zone_4', 'zone_5', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [0.000000, 0.028430]
#   p: range [-3367.353336, 511.861087]
#   Ux: range [-18.309331, 60.340796]
#   Uy: range [-5.637635, 61.462049]
#   implicit_distance: range [-3.354330, 0.000000]
#
# Global range for nut: [0.000000, 0.028471]
#
# Global range for p: [-3382.318376, 512.156588]
#
# Global range for Ux: [-18.309331, 60.340796]
#
# Global range for Uy: [-5.650903, 61.462049]
#
# --- Processing REMESHED Data ---
# ✅ Found 1232 surface points in REMESHED
# Drag Force: -83.303860, Lift Force: 259.515566
#
# --- Processing CLIPPED Data ---
# ✅ Found 1244 surface points in CLIPPED
# Drag Force: -81.259585, Lift Force: 253.053238
#
#
# ==================== Processing Sample: sample_000000012 ====================
#
# Processing REMESHED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'vtkOriginalPointIds', 'cell_ids', 'vtkOriginalCellIds', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [0.000000, 0.020504]
#   p: range [-3643.648189, 512.068588]
#   Ux: range [-20.493643, 62.614326]
#   Uy: range [-4.464159, 69.672942]
#   implicit_distance: range [-3.354465, 0.000000]
#
# Processing CLIPPED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'zone_0', 'zone_1', 'zone_2', 'zone_3', 'zone_4', 'zone_5', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [-0.000000, 0.020503]
#   p: range [-3622.554022, 511.785042]
#   Ux: range [-20.416287, 62.619253]
#   Uy: range [-4.458082, 64.208910]
#   implicit_distance: range [-3.354465, 0.000000]
#
# Global range for nut: [-0.000000, 0.020504]
#
# Global range for p: [-3643.648189, 512.068588]
#
# Global range for Ux: [-20.493643, 62.619253]
#
# Global range for Uy: [-4.464159, 69.672942]
#
# --- Processing REMESHED Data ---
# ✅ Found 1222 surface points in REMESHED
# Drag Force: -81.072633, Lift Force: 243.398352
#
# --- Processing CLIPPED Data ---
# ✅ Found 1233 surface points in CLIPPED
# Drag Force: -79.154493, Lift Force: 237.758176
#
#
# ==================== Processing Sample: sample_000000013 ====================
#
# Processing REMESHED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'vtkOriginalPointIds', 'cell_ids', 'vtkOriginalCellIds', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [0.000000, 0.004745]
#   p: range [-276.386375, 462.703527]
#   Ux: range [0.000000, 39.363822]
#   Uy: range [-19.469127, 15.927567]
#   implicit_distance: range [-3.354418, 0.000000]
#
# Processing CLIPPED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'zone_0', 'zone_1', 'zone_2', 'zone_3', 'zone_4', 'zone_5', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [0.000000, 0.004743]
#   p: range [-276.295933, 462.700256]
#   Ux: range [0.000000, 39.360524]
#   Uy: range [-19.447994, 15.927266]
#   implicit_distance: range [-3.354418, 0.000000]
#
# Global range for nut: [0.000000, 0.004745]
#
# Global range for p: [-276.386375, 462.703527]
#
# Global range for Ux: [0.000000, 39.363822]
#
# Global range for Uy: [-19.469127, 15.927567]
#
# --- Processing REMESHED Data ---
# ✅ Found 1670 surface points in REMESHED
# Drag Force: -14.379266, Lift Force: -7.790374
#
# --- Processing CLIPPED Data ---
# ✅ Found 1674 surface points in CLIPPED
# Drag Force: -14.368903, Lift Force: -7.573320
#
#
# ==================== Processing Sample: sample_000000014 ====================
#
# Processing REMESHED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'vtkOriginalPointIds', 'cell_ids', 'vtkOriginalCellIds', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [0.000000, 0.034419]
#   p: range [-3451.735703, 521.922354]
#   Ux: range [-35.270046, 59.487318]
#   Uy: range [-2.951432, 69.649031]
#   implicit_distance: range [-3.354368, 0.000000]
#
# Processing CLIPPED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'zone_0', 'zone_1', 'zone_2', 'zone_3', 'zone_4', 'zone_5', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [0.000000, 0.034388]
#   p: range [-3451.608349, 521.893898]
#   Ux: range [-35.038986, 59.433035]
#   Uy: range [-2.947514, 69.625009]
#   implicit_distance: range [-3.354368, 0.000000]
#
# Global range for nut: [0.000000, 0.034419]
#
# Global range for p: [-3451.735703, 521.922354]
#
# Global range for Ux: [-35.270046, 59.487318]
#
# Global range for Uy: [-2.951432, 69.649031]
#
# --- Processing REMESHED Data ---
# ✅ Found 891 surface points in REMESHED
# Drag Force: -94.953990, Lift Force: 261.477596
#
# --- Processing CLIPPED Data ---
# ✅ Found 908 surface points in CLIPPED
# Drag Force: -91.597031, Lift Force: 252.373343
#
#
# ==================== Processing Sample: sample_000000015 ====================
#
# Processing REMESHED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'vtkOriginalPointIds', 'cell_ids', 'vtkOriginalCellIds', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [0.000000, 0.005400]
#   p: range [-683.886314, 383.594365]
#   Ux: range [0.000000, 48.314523]
#   Uy: range [-6.848515, 26.843666]
#   implicit_distance: range [-3.354355, 0.000000]
#
# Processing CLIPPED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'zone_0', 'zone_1', 'zone_2', 'zone_3', 'zone_4', 'zone_5', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [-0.000000, 0.005389]
#   p: range [-683.344523, 383.963158]
#   Ux: range [-0.000000, 48.289734]
#   Uy: range [-6.790267, 26.826415]
#   implicit_distance: range [-3.354355, 0.000000]
#
# Global range for nut: [-0.000000, 0.005400]
#
# Global range for p: [-683.886314, 383.963158]
#
# Global range for Ux: [-0.000000, 48.314523]
#
# Global range for Uy: [-6.848515, 26.843666]
#
# --- Processing REMESHED Data ---
# ✅ Found 1159 surface points in REMESHED
# Drag Force: -21.166363, Lift Force: 110.887752
#
# --- Processing CLIPPED Data ---
# ✅ Found 1170 surface points in CLIPPED
# Drag Force: -20.697960, Lift Force: 108.214426
#
#
# ==================== Processing Sample: sample_000000016 ====================
#
# Processing REMESHED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'vtkOriginalPointIds', 'cell_ids', 'vtkOriginalCellIds', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [0.000000, 0.013571]
#   p: range [-3641.814127, 524.495154]
#   Ux: range [-21.097104, 70.579984]
#   Uy: range [-2.103678, 64.910150]
#   implicit_distance: range [-3.354327, 0.000000]
#
# Processing CLIPPED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'zone_0', 'zone_1', 'zone_2', 'zone_3', 'zone_4', 'zone_5', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [-0.000000, 0.013559]
#   p: range [-3649.442913, 524.419628]
#   Ux: range [-21.017519, 67.703631]
#   Uy: range [-2.102071, 64.831891]
#   implicit_distance: range [-3.354327, 0.000000]
#
# Global range for nut: [-0.000000, 0.013571]
#
# Global range for p: [-3649.442913, 524.495154]
#
# Global range for Ux: [-21.097104, 70.579984]
#
# Global range for Uy: [-2.103678, 64.910150]
#
# --- Processing REMESHED Data ---
# ✅ Found 1109 surface points in REMESHED
# Drag Force: -58.057336, Lift Force: 198.686705
#
# --- Processing CLIPPED Data ---
# ✅ Found 1114 surface points in CLIPPED
# Drag Force: -57.505931, Lift Force: 196.381339
#
#
# ==================== Processing Sample: sample_000000017 ====================
#
# Processing REMESHED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'vtkOriginalPointIds', 'cell_ids', 'vtkOriginalCellIds', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [0.000000, 0.004036]
#   p: range [-206.349854, 384.455022]
#   Ux: range [0.000000, 37.264625]
#   Uy: range [-16.971203, 12.508988]
#   implicit_distance: range [-3.354383, 0.000000]
#
# Processing CLIPPED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'zone_0', 'zone_1', 'zone_2', 'zone_3', 'zone_4', 'zone_5', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [-0.000000, 0.004035]
#   p: range [-205.845962, 383.693089]
#   Ux: range [-0.000000, 37.263777]
#   Uy: range [-16.939801, 12.496981]
#   implicit_distance: range [-3.354383, 0.000000]
#
# Global range for nut: [-0.000000, 0.004036]
#
# Global range for p: [-206.349854, 384.455022]
#
# Global range for Ux: [-0.000000, 37.264625]
#
# Global range for Uy: [-16.971203, 12.508988]
#
# --- Processing REMESHED Data ---
# ✅ Found 1123 surface points in REMESHED
# Drag Force: -12.482675, Lift Force: -7.753805
#
# --- Processing CLIPPED Data ---
# ✅ Found 1125 surface points in CLIPPED
# Drag Force: -12.478866, Lift Force: -7.724934
#
#
# ==================== Processing Sample: sample_000000018 ====================
#
# Processing REMESHED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'vtkOriginalPointIds', 'cell_ids', 'vtkOriginalCellIds', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [0.000000, 0.007071]
#   p: range [-570.677904, 511.683818]
#   Ux: range [0.000000, 46.437191]
#   Uy: range [-18.468891, 24.366039]
#   implicit_distance: range [-3.354307, 0.000000]
#
# Processing CLIPPED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'zone_0', 'zone_1', 'zone_2', 'zone_3', 'zone_4', 'zone_5', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [0.000000, 0.007062]
#   p: range [-570.482862, 511.455633]
#   Ux: range [-0.000000, 46.346137]
#   Uy: range [-18.467813, 24.364311]
#   implicit_distance: range [-3.354307, 0.000000]
#
# Global range for nut: [0.000000, 0.007071]
#
# Global range for p: [-570.677904, 511.683818]
#
# Global range for Ux: [-0.000000, 46.437191]
#
# Global range for Uy: [-18.468891, 24.366039]
#
# --- Processing REMESHED Data ---
# ✅ Found 2131 surface points in REMESHED
# Drag Force: -15.684796, Lift Force: 60.113188
#
# --- Processing CLIPPED Data ---
# ✅ Found 2138 surface points in CLIPPED
# Drag Force: -15.551476, Lift Force: 59.249737
#
#
# ==================== Processing Sample: sample_000000019 ====================
#
# Processing REMESHED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'vtkOriginalPointIds', 'cell_ids', 'vtkOriginalCellIds', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [0.000000, 0.005575]
#   p: range [-1177.225563, 517.378237]
#   Ux: range [0.000000, 49.617974]
#   Uy: range [-4.744771, 41.834691]
#   implicit_distance: range [-3.354346, 0.000000]
#
# Processing CLIPPED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'zone_0', 'zone_1', 'zone_2', 'zone_3', 'zone_4', 'zone_5', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [-0.000000, 0.005553]
#   p: range [-1177.514845, 516.404606]
#   Ux: range [-0.000000, 49.034303]
#   Uy: range [-4.749746, 41.832666]
#   implicit_distance: range [-3.354346, 0.000000]
#
# Global range for nut: [-0.000000, 0.005575]
#
# Global range for p: [-1177.514845, 517.378237]
#
# Global range for Ux: [-0.000000, 49.617974]
#
# Global range for Uy: [-4.749746, 41.834691]
#
# --- Processing REMESHED Data ---
# ✅ Found 1279 surface points in REMESHED
# Drag Force: -24.119077, Lift Force: 100.922101
#
# --- Processing CLIPPED Data ---
# ✅ Found 1292 surface points in CLIPPED
# Drag Force: -23.499942, Lift Force: 98.157157
#
#
# ==================== Processing Sample: sample_000000020 ====================
#
# Processing REMESHED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'vtkOriginalPointIds', 'cell_ids', 'vtkOriginalCellIds', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [0.000000, 0.016104]
#   p: range [-1204.021823, 528.611026]
#   Ux: range [-5.255015, 55.121591]
#   Uy: range [-5.844249, 45.054052]
#   implicit_distance: range [-3.354494, 0.000000]
#
# Processing CLIPPED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'zone_0', 'zone_1', 'zone_2', 'zone_3', 'zone_4', 'zone_5', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [-0.000000, 0.015936]
#   p: range [-1203.800252, 528.517907]
#   Ux: range [-5.245247, 55.051727]
#   Uy: range [-5.810457, 45.051632]
#   implicit_distance: range [-3.354494, 0.000000]
#
# Global range for nut: [-0.000000, 0.016104]
#
# Global range for p: [-1204.021823, 528.611026]
#
# Global range for Ux: [-5.255015, 55.121591]
#
# Global range for Uy: [-5.844249, 45.054052]
#
# --- Processing REMESHED Data ---
# ✅ Found 2181 surface points in REMESHED
# Drag Force: -41.254718, Lift Force: 144.679756
#
# --- Processing CLIPPED Data ---
# ✅ Found 2190 surface points in CLIPPED
# Drag Force: -40.555701, Lift Force: 142.050591
#
#
# ==================== Processing Sample: sample_000000021 ====================
#
# Processing REMESHED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'vtkOriginalPointIds', 'cell_ids', 'vtkOriginalCellIds', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [0.000000, 0.017801]
#   p: range [-1863.358779, 531.073876]
#   Ux: range [-13.757252, 57.478909]
#   Uy: range [-4.814825, 56.653895]
#   implicit_distance: range [-3.354674, 0.000000]
#
# Processing CLIPPED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'zone_0', 'zone_1', 'zone_2', 'zone_3', 'zone_4', 'zone_5', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [0.000000, 0.017786]
#   p: range [-1863.080395, 530.943229]
#   Ux: range [-13.747715, 57.427099]
#   Uy: range [-4.813056, 56.653671]
#   implicit_distance: range [-3.354674, 0.000000]
#
# Global range for nut: [0.000000, 0.017801]
#
# Global range for p: [-1863.358779, 531.073876]
#
# Global range for Ux: [-13.757252, 57.478909]
#
# Global range for Uy: [-4.814825, 56.653895]
#
# --- Processing REMESHED Data ---
# ✅ Found 1683 surface points in REMESHED
# Drag Force: -61.092031, Lift Force: 205.925815
#
# --- Processing CLIPPED Data ---
# ✅ Found 1689 surface points in CLIPPED
# Drag Force: -60.519501, Lift Force: 201.823511
#
#
# ==================== Processing Sample: sample_000000022 ====================
#
# Processing REMESHED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'vtkOriginalPointIds', 'cell_ids', 'vtkOriginalCellIds', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [0.000000, 0.006617]
#   p: range [-539.105390, 502.507568]
#   Ux: range [0.000000, 46.110163]
#   Uy: range [-20.320292, 20.746871]
#   implicit_distance: range [-3.354430, 0.000000]
#
# Processing CLIPPED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'zone_0', 'zone_1', 'zone_2', 'zone_3', 'zone_4', 'zone_5', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [0.000000, 0.006614]
#   p: range [-539.070580, 501.655078]
#   Ux: range [-0.000000, 46.102939]
#   Uy: range [-20.309903, 20.742506]
#   implicit_distance: range [-3.354430, 0.000000]
#
# Global range for nut: [0.000000, 0.006617]
#
# Global range for p: [-539.105390, 502.507568]
#
# Global range for Ux: [-0.000000, 46.110163]
#
# Global range for Uy: [-20.320292, 20.746871]
#
# --- Processing REMESHED Data ---
# ✅ Found 1815 surface points in REMESHED
# Drag Force: -14.237723, Lift Force: 79.856970
#
# --- Processing CLIPPED Data ---
# ✅ Found 1817 surface points in CLIPPED
# Drag Force: -14.261410, Lift Force: 79.483465
#
#
# ==================== Processing Sample: sample_000000023 ====================
#
# Processing REMESHED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'vtkOriginalPointIds', 'cell_ids', 'vtkOriginalCellIds', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [0.000000, 0.010748]
#   p: range [-1219.044690, 519.415771]
#   Ux: range [-5.118669, 53.491106]
#   Uy: range [-5.304420, 47.022362]
#   implicit_distance: range [-3.354591, 0.000000]
#
# Processing CLIPPED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'zone_0', 'zone_1', 'zone_2', 'zone_3', 'zone_4', 'zone_5', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [0.000000, 0.010745]
#   p: range [-1219.114408, 518.863657]
#   Ux: range [-5.084459, 53.475318]
#   Uy: range [-5.297173, 47.019796]
#   implicit_distance: range [-3.354591, 0.000000]
#
# Global range for nut: [0.000000, 0.010748]
#
# Global range for p: [-1219.114408, 519.415771]
#
# Global range for Ux: [-5.118669, 53.491106]
#
# Global range for Uy: [-5.304420, 47.022362]
#
# --- Processing REMESHED Data ---
# ✅ Found 1747 surface points in REMESHED
# Drag Force: -45.576878, Lift Force: 163.821806
#
# --- Processing CLIPPED Data ---
# ✅ Found 1746 surface points in CLIPPED
# Drag Force: -43.990292, Lift Force: 163.059231
#
#
# ==================== Processing Sample: sample_000000024 ====================
#
# Processing REMESHED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'vtkOriginalPointIds', 'cell_ids', 'vtkOriginalCellIds', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [0.000000, 0.005468]
#   p: range [-355.717488, 459.906848]
#   Ux: range [0.000000, 42.215516]
#   Uy: range [-17.419113, 18.144026]
#   implicit_distance: range [-3.354388, 0.000000]
#
# Processing CLIPPED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'zone_0', 'zone_1', 'zone_2', 'zone_3', 'zone_4', 'zone_5', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [0.000000, 0.005464]
#   p: range [-355.704661, 459.102532]
#   Ux: range [0.000000, 42.212987]
#   Uy: range [-17.404604, 18.152290]
#   implicit_distance: range [-3.354388, 0.000000]
#
# Global range for nut: [0.000000, 0.005468]
#
# Global range for p: [-355.717488, 459.906848]
#
# Global range for Ux: [0.000000, 42.215516]
#
# Global range for Uy: [-17.419113, 18.152290]
#
# --- Processing REMESHED Data ---
# ✅ Found 1457 surface points in REMESHED
# Drag Force: -11.325277, Lift Force: 84.768896
#
# --- Processing CLIPPED Data ---
# ✅ Found 1476 surface points in CLIPPED
# Drag Force: -10.954688, Lift Force: 81.498136
#
#
# ==================== Processing Sample: sample_000000025 ====================
#
# Processing REMESHED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'vtkOriginalPointIds', 'cell_ids', 'vtkOriginalCellIds', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [0.000000, 0.006167]
#   p: range [-516.584695, 529.796636]
#   Ux: range [0.000000, 45.312998]
#   Uy: range [-23.212536, 21.393357]
#   implicit_distance: range [-3.354353, 0.000000]
#
# Processing CLIPPED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'zone_0', 'zone_1', 'zone_2', 'zone_3', 'zone_4', 'zone_5', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [-0.000000, 0.006165]
#   p: range [-516.515958, 529.387454]
#   Ux: range [-0.000000, 45.308860]
#   Uy: range [-23.205194, 21.390891]
#   implicit_distance: range [-3.354353, 0.000000]
#
# Global range for nut: [-0.000000, 0.006167]
#
# Global range for p: [-516.584695, 529.796636]
#
# Global range for Ux: [-0.000000, 45.312998]
#
# Global range for Uy: [-23.212536, 21.393357]
#
# --- Processing REMESHED Data ---
# ✅ Found 2225 surface points in REMESHED
# Drag Force: -13.498552, Lift Force: 24.928491
#
# --- Processing CLIPPED Data ---
# ✅ Found 2227 surface points in CLIPPED
# Drag Force: -13.188812, Lift Force: 23.885794
#
#
# ==================== Processing Sample: sample_000000026 ====================
#
# Processing REMESHED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'vtkOriginalPointIds', 'cell_ids', 'vtkOriginalCellIds', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [0.000000, 0.006663]
#   p: range [-2871.456762, 531.098463]
#   Ux: range [-15.636372, 56.404154]
#   Uy: range [-2.925543, 42.865243]
#   implicit_distance: range [-3.354510, 0.000000]
#
# Processing CLIPPED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'zone_0', 'zone_1', 'zone_2', 'zone_3', 'zone_4', 'zone_5', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [-0.000000, 0.006649]
#   p: range [-2845.185590, 530.903313]
#   Ux: range [-15.568362, 56.411792]
#   Uy: range [-2.920844, 42.811170]
#   implicit_distance: range [-3.354510, 0.000000]
#
# Global range for nut: [-0.000000, 0.006663]
#
# Global range for p: [-2871.456762, 531.098463]
#
# Global range for Ux: [-15.636372, 56.411792]
#
# Global range for Uy: [-2.925543, 42.865243]
#
# --- Processing REMESHED Data ---
# ✅ Found 854 surface points in REMESHED
# Drag Force: -36.385925, Lift Force: 158.685180
#
# --- Processing CLIPPED Data ---
# ✅ Found 856 surface points in CLIPPED
# Drag Force: -36.416778, Lift Force: 158.131171
#
#
# ==================== Processing Sample: sample_000000027 ====================
#
# Processing REMESHED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'vtkOriginalPointIds', 'cell_ids', 'vtkOriginalCellIds', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [0.000000, 0.011903]
#   p: range [-1858.714289, 539.929151]
#   Ux: range [-9.681394, 57.393126]
#   Uy: range [-5.033818, 57.542570]
#   implicit_distance: range [-3.354616, 0.000000]
#
# Processing CLIPPED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'zone_0', 'zone_1', 'zone_2', 'zone_3', 'zone_4', 'zone_5', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [-0.000000, 0.011843]
#   p: range [-1857.330410, 539.749512]
#   Ux: range [-9.696053, 57.394585]
#   Uy: range [-5.032758, 57.547500]
#   implicit_distance: range [-3.354616, 0.000000]
#
# Global range for nut: [-0.000000, 0.011903]
#
# Global range for p: [-1858.714289, 539.929151]
#
# Global range for Ux: [-9.696053, 57.394585]
#
# Global range for Uy: [-5.033818, 57.547500]
#
# --- Processing REMESHED Data ---
# ✅ Found 1909 surface points in REMESHED
# Drag Force: -51.914680, Lift Force: 158.675655
#
# --- Processing CLIPPED Data ---
# ✅ Found 1910 surface points in CLIPPED
# Drag Force: -51.903546, Lift Force: 158.355439
#
#
# ==================== Processing Sample: sample_000000028 ====================
#
# Processing REMESHED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'vtkOriginalPointIds', 'cell_ids', 'vtkOriginalCellIds', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [0.000000, 0.005049]
#   p: range [-697.213676, 510.680240]
#   Ux: range [0.000000, 45.824688]
#   Uy: range [-31.006546, 15.080434]
#   implicit_distance: range [-3.354504, 0.000000]
#
# Processing CLIPPED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'zone_0', 'zone_1', 'zone_2', 'zone_3', 'zone_4', 'zone_5', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [0.000000, 0.005045]
#   p: range [-696.825604, 510.558262]
#   Ux: range [0.000000, 45.174777]
#   Uy: range [-31.015953, 14.914946]
#   implicit_distance: range [-3.354504, 0.000000]
#
# Global range for nut: [0.000000, 0.005049]
#
# Global range for p: [-697.213676, 510.680240]
#
# Global range for Ux: [0.000000, 45.824688]
#
# Global range for Uy: [-31.015953, 15.080434]
#
# --- Processing REMESHED Data ---
# ✅ Found 1733 surface points in REMESHED
# Drag Force: -12.930950, Lift Force: -3.554378
#
# --- Processing CLIPPED Data ---
# ✅ Found 1744 surface points in CLIPPED
# Drag Force: -12.709840, Lift Force: -3.524647
#
#
# ==================== Processing Sample: sample_000000029 ====================
#
# Processing REMESHED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'vtkOriginalPointIds', 'cell_ids', 'vtkOriginalCellIds', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [0.000000, 0.004600]
#   p: range [-439.710798, 474.581280]
#   Ux: range [0.000000, 43.098277]
#   Uy: range [-23.686211, 15.069958]
#   implicit_distance: range [-3.354461, 0.000000]
#
# Processing CLIPPED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'zone_0', 'zone_1', 'zone_2', 'zone_3', 'zone_4', 'zone_5', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [-0.000000, 0.004599]
#   p: range [-439.204683, 474.406640]
#   Ux: range [-0.000000, 43.095447]
#   Uy: range [-23.645720, 15.064434]
#   implicit_distance: range [-3.354461, 0.000000]
#
# Global range for nut: [-0.000000, 0.004600]
#
# Global range for p: [-439.710798, 474.581280]
#
# Global range for Ux: [-0.000000, 43.098277]
#
# Global range for Uy: [-23.686211, 15.069958]
#
# --- Processing REMESHED Data ---
# ✅ Found 1464 surface points in REMESHED
# Drag Force: -14.260323, Lift Force: -10.248672
#
# --- Processing CLIPPED Data ---
# ✅ Found 1468 surface points in CLIPPED
# Drag Force: -14.182628, Lift Force: -10.030112
#
#
# ==================== Processing Sample: sample_000000030 ====================
#
# Processing REMESHED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'vtkOriginalPointIds', 'cell_ids', 'vtkOriginalCellIds', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [0.000000, 0.022754]
#   p: range [-4132.598773, 548.094732]
#   Ux: range [-49.018740, 73.473113]
#   Uy: range [-3.172501, 71.931388]
#   implicit_distance: range [-3.354522, 0.000000]
#
# Processing CLIPPED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'zone_0', 'zone_1', 'zone_2', 'zone_3', 'zone_4', 'zone_5', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [0.000000, 0.022740]
#   p: range [-4129.891808, 547.913598]
#   Ux: range [-24.005912, 70.559847]
#   Uy: range [-3.159526, 72.017028]
#   implicit_distance: range [-3.354522, 0.000000]
#
# Global range for nut: [0.000000, 0.022754]
#
# Global range for p: [-4132.598773, 548.094732]
#
# Global range for Ux: [-49.018740, 73.473113]
#
# Global range for Uy: [-3.172501, 72.017028]
#
# --- Processing REMESHED Data ---
# ✅ Found 1028 surface points in REMESHED
# Drag Force: -84.830081, Lift Force: 263.497693
#
# --- Processing CLIPPED Data ---
# ✅ Found 1044 surface points in CLIPPED
# Drag Force: -81.954190, Lift Force: 254.052907
#
#
# ==================== Processing Sample: sample_000000031 ====================
#
# Processing REMESHED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'vtkOriginalPointIds', 'cell_ids', 'vtkOriginalCellIds', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [0.000000, 0.012602]
#   p: range [-2638.686321, 541.243739]
#   Ux: range [-27.901797, 63.755685]
#   Uy: range [-2.880038, 57.932210]
#   implicit_distance: range [-3.354245, 0.000000]
#
# Processing CLIPPED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'zone_0', 'zone_1', 'zone_2', 'zone_3', 'zone_4', 'zone_5', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [0.000000, 0.012609]
#   p: range [-2637.362607, 541.101614]
#   Ux: range [-27.844612, 63.773067]
#   Uy: range [-2.877536, 57.889298]
#   implicit_distance: range [-3.354245, 0.000000]
#
# Global range for nut: [0.000000, 0.012609]
#
# Global range for p: [-2638.686321, 541.243739]
#
# Global range for Ux: [-27.901797, 63.773067]
#
# Global range for Uy: [-2.880038, 57.932210]
#
# --- Processing REMESHED Data ---
# ✅ Found 821 surface points in REMESHED
# Drag Force: -55.822729, Lift Force: 215.570630
#
# --- Processing CLIPPED Data ---
# ✅ Found 828 surface points in CLIPPED
# Drag Force: -55.198593, Lift Force: 212.434283
#
#
# ==================== Processing Sample: sample_000000032 ====================
#
# Processing REMESHED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'vtkOriginalPointIds', 'cell_ids', 'vtkOriginalCellIds', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [0.000000, 0.005742]
#   p: range [-523.252710, 478.244409]
#   Ux: range [0.000000, 45.425940]
#   Uy: range [-10.069672, 29.605359]
#   implicit_distance: range [-3.354479, 0.000000]
#
# Processing CLIPPED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'zone_0', 'zone_1', 'zone_2', 'zone_3', 'zone_4', 'zone_5', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [0.000000, 0.005738]
#   p: range [-523.094941, 477.627862]
#   Ux: range [0.000000, 45.422293]
#   Uy: range [-10.068068, 29.610038]
#   implicit_distance: range [-3.354479, 0.000000]
#
# Global range for nut: [0.000000, 0.005742]
#
# Global range for p: [-523.252710, 478.244409]
#
# Global range for Ux: [0.000000, 45.425940]
#
# Global range for Uy: [-10.069672, 29.610038]
#
# --- Processing REMESHED Data ---
# ✅ Found 1604 surface points in REMESHED
# Drag Force: -19.330371, Lift Force: 82.004230
#
# --- Processing CLIPPED Data ---
# ✅ Found 1607 surface points in CLIPPED
# Drag Force: -19.238716, Lift Force: 81.455657
#
#
# ==================== Processing Sample: sample_000000033 ====================
#
# Processing REMESHED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'vtkOriginalPointIds', 'cell_ids', 'vtkOriginalCellIds', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [0.000000, 0.003899]
#   p: range [-157.925412, 354.608885]
# ...
#
# Global range for Uy: [-80.855056, 19.202351]
#
# --- Processing REMESHED Data ---
# ✅ Found 866 surface points in REMESHED
# Drag Force: -6.092095, Lift Force: -118.645712
#
# --- Processing CLIPPED Data ---
# ✅ Found 878 surface points in CLIPPED
# Drag Force: -6.206181, Lift Force: -116.521749
#
#
# ==================== Processing Sample: sample_000000991 ====================
#
# Processing REMESHED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'vtkOriginalPointIds', 'cell_ids', 'vtkOriginalCellIds', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [0.000000, 0.022424]
#   p: range [-9836.195199, 4230.272583]
#   Ux: range [-19.027471, 151.013032]
#   Uy: range [-15.581934, 132.890811]
#   implicit_distance: range [-3.354675, 0.000000]
#
# Processing CLIPPED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'zone_0', 'zone_1', 'zone_2', 'zone_3', 'zone_4', 'zone_5', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [-0.000000, 0.022416]
#   p: range [-9816.458793, 4228.690769]
#   Ux: range [-19.001256, 150.389260]
#   Uy: range [-15.581229, 132.873897]
#   implicit_distance: range [-3.354675, 0.000000]
#
# Global range for nut: [-0.000000, 0.022424]
#
# Global range for p: [-9836.195199, 4230.272583]
#
# Global range for Ux: [-19.027471, 151.013032]
#
# Global range for Uy: [-15.581934, 132.890811]
#
# --- Processing REMESHED Data ---
# ✅ Found 1885 surface points in REMESHED
# Drag Force: -262.351990, Lift Force: 1124.934021
#
# --- Processing CLIPPED Data ---
# ✅ Found 1884 surface points in CLIPPED
# Drag Force: -262.925171, Lift Force: 1126.698225
#
#
# ==================== Processing Sample: sample_000000992 ====================
#
# Processing REMESHED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'vtkOriginalPointIds', 'cell_ids', 'vtkOriginalCellIds', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [0.000000, 0.011542]
#   p: range [-11653.370387, 4171.969437]
#   Ux: range [0.000000, 163.412946]
#   Uy: range [-78.275345, 44.658545]
#   implicit_distance: range [-3.354378, 0.000000]
#
# Processing CLIPPED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'zone_0', 'zone_1', 'zone_2', 'zone_3', 'zone_4', 'zone_5', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [0.000000, 0.011526]
#   p: range [-11655.385194, 4171.241143]
#   Ux: range [0.000000, 163.324264]
#   Uy: range [-78.093490, 44.619412]
#   implicit_distance: range [-3.354378, 0.000000]
#
# Global range for nut: [0.000000, 0.011542]
#
# Global range for p: [-11655.385194, 4171.969437]
#
# Global range for Ux: [0.000000, 163.412946]
#
# Global range for Uy: [-78.275345, 44.658545]
#
# --- Processing REMESHED Data ---
# ✅ Found 1227 surface points in REMESHED
# Drag Force: 21.930315, Lift Force: 341.423849
#
# --- Processing CLIPPED Data ---
# ✅ Found 1241 surface points in CLIPPED
# Drag Force: 20.844868, Lift Force: 331.157863
#
#
# ==================== Processing Sample: sample_000000993 ====================
#
# Processing REMESHED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'vtkOriginalPointIds', 'cell_ids', 'vtkOriginalCellIds', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [0.000000, 0.024372]
#   p: range [-10082.439408, 4242.849195]
#   Ux: range [-19.973540, 150.634314]
#   Uy: range [-16.621340, 134.697356]
#   implicit_distance: range [-3.354694, 0.000000]
#
# Processing CLIPPED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'zone_0', 'zone_1', 'zone_2', 'zone_3', 'zone_4', 'zone_5', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [-0.000000, 0.024360]
#   p: range [-10067.980611, 4241.883634]
#   Ux: range [-19.940282, 150.598512]
#   Uy: range [-16.598853, 134.684745]
#   implicit_distance: range [-3.354694, 0.000000]
#
# Global range for nut: [-0.000000, 0.024372]
#
# Global range for p: [-10082.439408, 4242.849195]
#
# Global range for Ux: [-19.973540, 150.634314]
#
# Global range for Uy: [-16.621340, 134.697356]
#
# --- Processing REMESHED Data ---
# ✅ Found 1835 surface points in REMESHED
# Drag Force: -291.540962, Lift Force: 1320.674398
#
# --- Processing CLIPPED Data ---
# ✅ Found 1845 surface points in CLIPPED
# Drag Force: -285.711451, Lift Force: 1293.133579
#
#
# ==================== Processing Sample: sample_000000994 ====================
#
# Processing REMESHED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'vtkOriginalPointIds', 'cell_ids', 'vtkOriginalCellIds', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [0.000000, 0.017608]
#   p: range [-18977.351580, 4287.025232]
#   Ux: range [-40.398223, 165.210439]
#   Uy: range [-9.954994, 159.577491]
#   implicit_distance: range [-3.354451, 0.000000]
#
# Processing CLIPPED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'zone_0', 'zone_1', 'zone_2', 'zone_3', 'zone_4', 'zone_5', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [-0.000000, 0.017564]
#   p: range [-19005.530460, 4285.414165]
#   Ux: range [-40.440026, 165.202915]
#   Uy: range [-9.872714, 159.693633]
#   implicit_distance: range [-3.354451, 0.000000]
#
# Global range for nut: [-0.000000, 0.017608]
#
# Global range for p: [-19005.530460, 4287.025232]
#
# Global range for Ux: [-40.440026, 165.210439]
#
# Global range for Uy: [-9.954994, 159.693633]
#
# --- Processing REMESHED Data ---
# ✅ Found 1357 surface points in REMESHED
# Drag Force: -235.969043, Lift Force: 1118.365545
#
# --- Processing CLIPPED Data ---
# ✅ Found 1357 surface points in CLIPPED
# Drag Force: -236.499028, Lift Force: 1117.880612
#
#
# ==================== Processing Sample: sample_000000995 ====================
#
# Processing REMESHED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'vtkOriginalPointIds', 'cell_ids', 'vtkOriginalCellIds', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [0.000000, 0.050836]
#   p: range [-17849.765114, 4317.038129]
#   Ux: range [-32.022882, 172.440672]
#   Uy: range [-14.238351, 172.110713]
#   implicit_distance: range [-3.354223, 0.000000]
#
# Processing CLIPPED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'zone_0', 'zone_1', 'zone_2', 'zone_3', 'zone_4', 'zone_5', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [0.000000, 0.049408]
#   p: range [-17824.411055, 4315.901980]
#   Ux: range [-31.957166, 171.681250]
#   Uy: range [-14.237691, 172.032099]
#   implicit_distance: range [-3.354223, 0.000000]
#
# Global range for nut: [0.000000, 0.050836]
#
# Global range for p: [-17849.765114, 4317.038129]
#
# Global range for Ux: [-32.022882, 172.440672]
#
# Global range for Uy: [-14.238351, 172.110713]
#
# --- Processing REMESHED Data ---
# ✅ Found 2283 surface points in REMESHED
# Drag Force: -401.724688, Lift Force: 1377.877041
#
# --- Processing CLIPPED Data ---
# ✅ Found 2299 surface points in CLIPPED
# Drag Force: -389.419216, Lift Force: 1334.596123
#
#
# ==================== Processing Sample: sample_000000996 ====================
#
# Processing REMESHED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'vtkOriginalPointIds', 'cell_ids', 'vtkOriginalCellIds', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [0.000000, 0.011163]
#   p: range [-6109.474198, 4192.942583]
#   Ux: range [0.000000, 130.572629]
#   Uy: range [-22.510711, 93.569609]
#   implicit_distance: range [-3.354380, 0.000000]
#
# Processing CLIPPED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'zone_0', 'zone_1', 'zone_2', 'zone_3', 'zone_4', 'zone_5', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [-0.000000, 0.011151]
#   p: range [-6102.495835, 4187.941357]
#   Ux: range [-0.000000, 129.639033]
#   Uy: range [-21.460134, 93.450199]
#   implicit_distance: range [-3.354380, 0.000000]
#
# Global range for nut: [-0.000000, 0.011163]
#
# Global range for p: [-6109.474198, 4192.942583]
#
# Global range for Ux: [-0.000000, 130.572629]
#
# Global range for Uy: [-22.510711, 93.569609]
#
# --- Processing REMESHED Data ---
# ✅ Found 1247 surface points in REMESHED
# Drag Force: -83.020258, Lift Force: 513.228925
#
# --- Processing CLIPPED Data ---
# ✅ Found 1263 surface points in CLIPPED
# Drag Force: -80.495047, Lift Force: 495.802992
#
#
# ==================== Processing Sample: sample_000000997 ====================
#
# Processing REMESHED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'vtkOriginalPointIds', 'cell_ids', 'vtkOriginalCellIds', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [0.000000, 0.020208]
#   p: range [-21750.917189, 4288.704669]
#   Ux: range [-51.351866, 173.872643]
#   Uy: range [-9.641808, 178.413128]
#   implicit_distance: range [-3.354602, 0.000000]
#
# Processing CLIPPED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'zone_0', 'zone_1', 'zone_2', 'zone_3', 'zone_4', 'zone_5', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [0.000000, 0.020185]
#   p: range [-21740.117015, 4287.599747]
#   Ux: range [-41.585246, 173.824798]
#   Uy: range [-9.639600, 160.942915]
#   implicit_distance: range [-3.354602, 0.000000]
#
# Global range for nut: [0.000000, 0.020208]
#
# Global range for p: [-21750.917189, 4288.704669]
#
# Global range for Ux: [-51.351866, 173.872643]
#
# Global range for Uy: [-9.641808, 178.413128]
#
# --- Processing REMESHED Data ---
# ✅ Found 1466 surface points in REMESHED
# Drag Force: -311.271294, Lift Force: 1299.417044
#
# --- Processing CLIPPED Data ---
# ✅ Found 1475 surface points in CLIPPED
# Drag Force: -305.812346, Lift Force: 1274.299550
#
#
# ==================== Processing Sample: sample_000000998 ====================
#
# Processing REMESHED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'vtkOriginalPointIds', 'cell_ids', 'vtkOriginalCellIds', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [0.000000, 0.016129]
#   p: range [-5492.214291, 4235.288435]
#   Ux: range [0.000000, 136.816631]
#   Uy: range [-33.736746, 92.163137]
#   implicit_distance: range [-3.354380, 0.000000]
#
# Processing CLIPPED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'zone_0', 'zone_1', 'zone_2', 'zone_3', 'zone_4', 'zone_5', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [0.000000, 0.016125]
#   p: range [-5491.108139, 4232.789345]
#   Ux: range [0.000000, 136.247708]
#   Uy: range [-28.310399, 92.137953]
#   implicit_distance: range [-3.354380, 0.000000]
#
# Global range for nut: [0.000000, 0.016129]
#
# Global range for p: [-5492.214291, 4235.288435]
#
# Global range for Ux: [0.000000, 136.816631]
#
# Global range for Uy: [-33.736746, 92.163137]
#
# --- Processing REMESHED Data ---
# ✅ Found 1946 surface points in REMESHED
# Drag Force: -100.040827, Lift Force: 672.000371
#
# --- Processing CLIPPED Data ---
# ✅ Found 1950 surface points in CLIPPED
# Drag Force: -97.047486, Lift Force: 656.384106
#
#
# ==================== Processing Sample: sample_000000999 ====================
#
# Processing REMESHED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'vtkOriginalPointIds', 'cell_ids', 'vtkOriginalCellIds', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [0.000000, 0.017225]
#   p: range [-6491.240060, 4347.334939]
#   Ux: range [-1.339502, 136.634022]
#   Uy: range [-22.084814, 113.063141]
#   implicit_distance: range [-3.354375, 0.000000]
#
# Processing CLIPPED mesh: mesh_000000000.cgns
#   Available arrays: ['Ux', 'Uy', 'implicit_distance', 'nut', 'p', 'zone_0', 'zone_1', 'zone_2', 'zone_3', 'zone_4', 'zone_5', 'vtkValidPointMask', 'Normals', 'TextureCoordinates', 'vtkGhostType', 'vtkGhostType']
#   Resolution: 513x513
#   nut: range [-0.000000, 0.017189]
#   p: range [-6475.435311, 4344.533107]
#   Ux: range [-0.271162, 136.623741]
#   Uy: range [-22.087090, 113.033202]
#   implicit_distance: range [-3.354375, 0.000000]
#
# Global range for nut: [-0.000000, 0.017225]
#
# Global range for p: [-6491.240060, 4347.334939]
#
# Global range for Ux: [-1.339502, 136.634022]
#
# Global range for Uy: [-22.087090, 113.063141]
#
# --- Processing REMESHED Data ---
# ✅ Found 1728 surface points in REMESHED
# Drag Force: -172.278800, Lift Force: 1073.850718
#
# --- Processing CLIPPED Data ---
# ✅ Found 1729 surface points in CLIPPED
# Drag Force: -172.423278, Lift Force: 1058.379644
#
#
# ✅ All samples processed. Results saved to 'coefficient_comparison_results.csv'
#
#
# ============================================================
# === FINAL SAMPLE (sample_000000999) COMPARISON ===
# ============================================================
# | Metric                    | Remeshed     | Clipped      | Difference (%)  |
# |---------------------------|--------------|--------------|------------------|
# | drag_coefficient          | -344.557601  | -344.846555  | 0.08            |
# | lift_coefficient          | 2147.701436  | 2116.759287  | -1.44           |
# | pressure_drag_coeff       | -272.408312  | -272.640673  | 0.09            |
# | viscous_drag_coeff        | -75.305562   | -75.316677   | 0.01            |
# ============================================================
#              sample  remeshed_cd  clipped_cd  reference_cd  cd_diff_percent  \
# 0  sample_000000000   -31.404574  -31.200064      0.010637        -0.651213
# 1  sample_000000001   -42.809603  -41.285300      0.010921        -3.560656
# 2  sample_000000002  -151.851885 -151.361983      0.029255        -0.322618
# 3  sample_000000003   -34.697698  -34.791902      0.011212         0.271497
# 4  sample_000000004   -38.726895  -38.660600      0.011948        -0.171186
#
#    remeshed_cl  clipped_cl  reference_cl  cl_diff_percent  \
# 0   -77.362372  -77.647355     -0.321047         0.368374
# 1   161.145464  153.908135      0.569220        -4.491177
# 2   463.658896  461.744132      1.620365        -0.412968
# 3   -81.797301  -82.292232     -0.309718         0.605070
# 4   145.541946  145.064030      0.526712        -0.328370
#
#    remeshed_pressure_drag  clipped_pressure_drag  pressure_drag_diff_percent  \
# 0               -5.966590              -5.883925                   -1.385465
# 1              -17.276218             -16.529881                   -4.320030
# 2             -133.939607            -133.426137                   -0.383360
# 3               -8.406206              -8.338329                   -0.807459
# 4              -13.102824             -13.046711                   -0.428251
#
#    remeshed_viscous_drag  clipped_viscous_drag  viscous_drag_diff_percent
# 0             -25.535899            -25.414415                  -0.475741
# 1             -25.709486            -24.923611                  -3.056749
# 2             -19.847752            -19.863326                   0.078468
# 3             -26.374747            -26.537330                   0.616437
# 4             -25.745977            -25.735395                  -0.041103

# %%
# Advanced CFD-based drag and lift coefficient calculation

def advanced_force_calculation(mesh_data, reference_conditions):
    """
    Advanced method for computing drag and lift coefficients using CFD principles.
    
    This method implements:
    1. Proper surface integration using control volume approach
    2. Momentum equation-based force calculation
    3. Far-field force calculation for validation
    4. Proper handling of turbulent flows
    
    Args:
        mesh_data (dict): Flow field data
        reference_conditions (dict): Reference flow conditions
    
    Returns:
        dict: Comprehensive force analysis results
    """
    
    print("=== Advanced CFD Force Calculation ===")
    
    # Extract flow variables
    p = mesh_data['p']        # Pressure
    u = mesh_data['Ux']       # X-velocity
    v = mesh_data['Uy']       # Y-velocity
    nut = mesh_data.get('nut', np.zeros_like(p))  # Turbulent viscosity
    
    # Reference conditions
    rho_inf = reference_conditions.get('density', 1.225)      # kg/m³
    u_inf = reference_conditions.get('velocity', 50.0)       # m/s
    mu = reference_conditions.get('viscosity', 1.81e-5)      # Pa·s
    chord = reference_conditions.get('chord', 1.0)           # m
    
    # Method 1: Surface pressure integration (most common)
    def surface_pressure_integration():
        """Calculate forces by integrating pressure over airfoil surface"""
        
        # Find airfoil surface using level set or wall distance
        if 'implicit_distance' in mesh_data:
            surface_mask = np.abs(mesh_data['implicit_distance']) < 0.005
        else:
            # Alternative: use stagnation points and low velocity regions
            vel_mag = np.sqrt(u**2 + v**2)
            surface_mask = vel_mag < 0.05 * u_inf
        
        if not np.any(surface_mask):
            return 0, 0, "No surface found"
        
        # Get surface coordinates
        y_coords, x_coords = np.where(surface_mask)
        n_points = len(x_coords)
        
        if n_points < 20:
            return 0, 0, f"Insufficient surface points: {n_points}"
        
        # Sort points to form a closed contour
        # This is crucial for proper integration
        center_x, center_y = np.mean(x_coords), np.mean(y_coords)
        angles = np.arctan2(y_coords - center_y, x_coords - center_x)
        sorted_indices = np.argsort(angles)
        
        x_surface = x_coords[sorted_indices]
        y_surface = y_coords[sorted_indices]
        p_surface = p[y_surface, x_surface]
        
        # Calculate surface normals and tangents
        dx = np.diff(x_surface, append=x_surface[0])
        dy = np.diff(y_surface, append=y_surface[0])
        ds = np.sqrt(dx**2 + dy**2)  # Surface element length
        
        # Outward normal vectors (perpendicular to surface)
        nx = dy / (ds + 1e-12)  # Normal x-component
        ny = -dx / (ds + 1e-12) # Normal y-component
        
        # Integrate pressure forces
        # F = ∫ p * n * ds
        force_x = np.sum(p_surface * nx * ds)
        force_y = np.sum(p_surface * ny * ds)
        
        return force_x, force_y, f"Surface integration with {n_points} points"
    
    # Method 2: Control volume momentum analysis
    def control_volume_method():
        """Calculate forces using momentum equation in control volume"""
        
        # Define control volume boundaries (far from airfoil)
        h, w = p.shape
        margin = min(h, w) // 10
        
        # Inlet boundary (left)
        inlet_u = u[:, margin]
        inlet_p = p[:, margin]
        
        # Outlet boundary (right)  
        outlet_u = u[:, -margin]
        outlet_p = p[:, -margin]
        
        # Top and bottom boundaries
        top_v = v[margin, :]
        top_p = p[margin, :]
        bottom_v = v[-margin, :]
        bottom_p = p[-margin, :]
        
        # Momentum flux calculation
        # Force = ∫∫ (p + ρu²) dA - momentum flux
        
        # X-direction force (drag)
        inlet_momentum_flux = np.sum(rho_inf * inlet_u**2 + inlet_p)
        outlet_momentum_flux = np.sum(rho_inf * outlet_u**2 + outlet_p)
        
        drag_force = inlet_momentum_flux - outlet_momentum_flux
        
        # Y-direction force (lift)  
        top_momentum_flux = np.sum(rho_inf * top_v**2 + top_p)
        bottom_momentum_flux = np.sum(rho_inf * bottom_v**2 + bottom_p)
        
        lift_force = top_momentum_flux - bottom_momentum_flux
        
        return drag_force, lift_force, "Control volume momentum method"
    
    # Method 3: Viscous stress integration
    def viscous_stress_integration():
        """Add viscous stress contribution to forces"""
        
        # Calculate velocity gradients
        dudy, dudx = np.gradient(u)
        dvdy, dvdx = np.gradient(v)
        
        # Stress tensor components
        mu_total = mu + rho_inf * nut  # Total viscosity (laminar + turbulent)
        
        tau_xx = mu_total * 2 * dudx
        tau_yy = mu_total * 2 * dvdy
        tau_xy = mu_total * (dudy + dvdx)
        
        # For proper implementation, we need surface integration of viscous stress
        # This is a simplified version
        viscous_drag = np.sum(tau_xx) * (1.0 / (u.shape[0] * u.shape[1]))
        viscous_lift = np.sum(tau_xy) * (1.0 / (u.shape[0] * u.shape[1]))
        
        return viscous_drag, viscous_lift, "Viscous stress integration"
    
    # Calculate forces using multiple methods
    print("\nCalculating forces using multiple methods:")
    
    # Surface pressure integration
    fp_x, fp_y, method1_info = surface_pressure_integration()
    print(f"1. {method1_info}")
    print(f"   Pressure forces: Fx = {fp_x:.6f}, Fy = {fp_y:.6f}")
    
    # Control volume method
    fcv_x, fcv_y, method2_info = control_volume_method()
    print(f"2. {method2_info}")
    print(f"   CV forces: Fx = {fcv_x:.6f}, Fy = {fcv_y:.6f}")
    
    # Viscous stress
    fv_x, fv_y, method3_info = viscous_stress_integration()
    print(f"3. {method3_info}")
    print(f"   Viscous forces: Fx = {fv_x:.6f}, Fy = {fv_y:.6f}")
    
    # Combine results
    total_force_x = fp_x + fv_x
    total_force_y = fp_y + fv_y
    
    # Non-dimensionalize to get coefficients
    q_inf = 0.5 * rho_inf * u_inf**2  # Dynamic pressure
    
    cd = total_force_x / (q_inf * chord)
    cl = total_force_y / (q_inf * chord)
    
    # Also compute coefficients from control volume method for comparison
    cd_cv = fcv_x / (q_inf * chord)
    cl_cv = fcv_y / (q_inf * chord)
    
    results = {
        'cd_surface': cd,
        'cl_surface': cl,
        'cd_control_volume': cd_cv,
        'cl_control_volume': cl_cv,
        'pressure_forces': (fp_x, fp_y),
        'viscous_forces': (fv_x, fv_y),
        'reference_dynamic_pressure': q_inf,
        'chord_length': chord
    }
    
    print(f"\n=== FINAL RESULTS ===")
    print(f"Surface Integration Method:")
    print(f"  Cd = {cd:.6f}, Cl = {cl:.6f}")
    print(f"Control Volume Method:")
    print(f"  Cd = {cd_cv:.6f}, Cl = {cl_cv:.6f}")
    print(f"Reference dynamic pressure: {q_inf:.3f} Pa")
    
    return results

# Example usage with reference conditions
reference_conditions = {
    'density': 1.225,      # kg/m³ (air at sea level)
    'velocity': 50.0,      # m/s (freestream velocity)
    'viscosity': 1.81e-5,  # Pa·s (air viscosity)
    'chord': 1.0,          # m (airfoil chord length)
}

print("Demonstrating advanced force calculation method...")
print("Note: This would use the remeshed_data for analysis")
print("To run: advanced_results = advanced_force_calculation(remeshed_data, reference_conditions)")
advanced_results = advanced_force_calculation(remeshed_data, reference_conditions)
adv_results_clipped = advanced_force_calculation(clipped_data, reference_conditions)
# Out:
# Demonstrating advanced force calculation method...
# Note: This would use the remeshed_data for analysis
# To run: advanced_results = advanced_force_calculation(remeshed_data, reference_conditions)
# === Advanced CFD Force Calculation ===
#
# Calculating forces using multiple methods:
# 1. Surface integration with 1569 points
#    Pressure forces: Fx = 935238.120048, Fy = 868989.901346
# 2. Control volume momentum method
#    CV forces: Fx = -17923.742819, Fy = 237268.923181
# 3. Viscous stress integration
#    Viscous forces: Fx = 0.000050, Fy = 0.000084
#
# === FINAL RESULTS ===
# Surface Integration Method:
#   Cd = 610.767752, Cl = 567.503609
# Control Volume Method:
#   Cd = -11.705301, Cl = 154.951134
# Reference dynamic pressure: 1531.250 Pa
# === Advanced CFD Force Calculation ===
#
# Calculating forces using multiple methods:
# 1. Surface integration with 1592 points
#    Pressure forces: Fx = 104671.585613, Fy = 1631087.544814
# 2. Control volume momentum method
#    CV forces: Fx = -7743.435356, Fy = 237461.455755
# 3. Viscous stress integration
#    Viscous forces: Fx = 0.000052, Fy = 0.000084
#
# === FINAL RESULTS ===
# Surface Integration Method:
#   Cd = 68.356954, Cl = 1065.200029
# Control Volume Method:
#   Cd = -5.056937, Cl = 155.076869
# Reference dynamic pressure: 1531.250 Pa

# %%
# read output_csv_path
import pandas as pd
results_df = pd.read_csv(output_csv_path)
print("\nResults from CSV:")
results_df.head()
# Out:
# Results from CSV:
#              sample  remeshed_cd  clipped_cd  reference_cd  cd_diff_percent  \
# 0  sample_000000000   -31.404574  -31.200064      0.010637        -0.651213
# 1  sample_000000001   -42.809603  -41.285300      0.010921        -3.560656
# 2  sample_000000002  -151.851885 -151.361983      0.029255        -0.322618
# 3  sample_000000003   -34.697698  -34.791902      0.011212         0.271497
# 4  sample_000000004   -38.726895  -38.660600      0.011948        -0.171186
#
#    remeshed_cl  clipped_cl  reference_cl  cl_diff_percent  \
# 0   -77.362372  -77.647355     -0.321047         0.368374
# 1   161.145464  153.908135      0.569220        -4.491177
# 2   463.658896  461.744132      1.620365        -0.412968
# 3   -81.797301  -82.292232     -0.309718         0.605070
# 4   145.541946  145.064030      0.526712        -0.328370
#
#    remeshed_pressure_drag  clipped_pressure_drag  pressure_drag_diff_percent  \
# 0               -5.966590              -5.883925                   -1.385465
# 1              -17.276218             -16.529881                   -4.320030
# 2             -133.939607            -133.426137                   -0.383360
# 3               -8.406206              -8.338329                   -0.807459
# 4              -13.102824             -13.046711                   -0.428251
#
#    remeshed_viscous_drag  clipped_viscous_drag  viscous_drag_diff_percent
# 0             -25.535899            -25.414415                  -0.475741
# 1             -25.709486            -24.923611                  -3.056749
# 2             -19.847752            -19.863326                   0.078468
# 3             -26.374747            -26.537330                   0.616437
# 4             -25.745977            -25.735395                  -0.041103

# %%
# get min max of drag and lift coefficients percentage sample,remeshed_cd,clipped_cd,reference_cd,cd_diff_percent,remeshed_cl,clipped_cl,reference_cl,cl_diff_percent,remeshed_pressure_drag,clipped_pressure_drag,pressure_drag_diff_percent,remeshed_viscous_drag,clipped_viscous_drag,viscous_drag_diff_percent
def get_min_max_coefficients(results_df):
    """
    Get the minimum and maximum coefficients from the results DataFrame.
    
    Args:
        results_df (pd.DataFrame): DataFrame containing coefficient results.
    
    Returns:
        dict: Dictionary with min and max values for each coefficient.
    """
    coefficients = { 
        'cd_percent_diff': (results_df['cd_diff_percent'].min(), results_df['cd_diff_percent'].max()),
        'cl_percent_diff': (results_df['cl_diff_percent'].min(), results_df['cl_diff_percent'].max()), 
        'pressure_drag_diff_percent': (results_df['pressure_drag_diff_percent'].min(), results_df['pressure_drag_diff_percent'].max()),
        'viscous_drag_diff_percent': (results_df['viscous_drag_diff_percent'].min(), results_df['viscous_drag_diff_percent'].max())
    }
    return coefficients

min_max_coeffs = get_min_max_coefficients(results_df)
print("\nMinimum and Maximum Coefficients:")
for key, value in min_max_coeffs.items():
    print(f"{key}: {value[0]:.6f}  {value[1]:.6f}")
    min_value, max_value = value
    # divide them into 3 bins
    low_bin = min_value + (max_value - min_value) / 3
    high_bin = min_value + 2 * (max_value - min_value) / 3
    print(f"Bins for {key}: Low < {low_bin:.6f}, Medium < {high_bin:.6f}, High >= {high_bin:.6f}")
# Out:
# Minimum and Maximum Coefficients:
# cd_percent_diff: -23.202029  39.786285
# Bins for cd_percent_diff: Low < -2.205924, Medium < 18.790180, High >= 18.790180
# cl_percent_diff: -300.309539  73.738826
# Bins for cl_percent_diff: Low < -175.626750, Medium < -50.943962, High >= -50.943962
# pressure_drag_diff_percent: -481.123633  597.206932
# Bins for pressure_drag_diff_percent: Low < -121.680111, Medium < 237.763411, High >= 237.763411
# viscous_drag_diff_percent: -7.914196  1.381432
# Bins for viscous_drag_diff_percent: Low < -4.815653, Medium < -1.717111, High >= -1.717111
